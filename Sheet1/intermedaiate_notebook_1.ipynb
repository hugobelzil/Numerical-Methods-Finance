# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as lin
import scipy.sparse as sp


# Set how floating-point errors are handled.
np.seterr(all='raise')


def initial_value(x):
    return np.sin(np.pi/2 * x)


#### exact solution at t=1 ####
def exact_solution_at_1(x):
    # todo 3 a)
    return np.exp(-(np.pi**2)/4) * np.sin(np.pi * x / 2)



#### numerical scheme ####
def eulerexplicit(N, M):
    # building auxiliary variables
    h = 1/N
    k = 1/M

    # First build u_i^0 = u0(ih)
    bc = np.linspace(0, 1, N + 1)[1:]
    bc = np.sin(np.pi * bc / 2)
    
    # Building the matrix G
    diagonal = np.ones(N)
    upper = np.ones(N-1)
    lower = np.ones(N-1)
    lower[-1] = 2.0
    G = sp.diags([lower, -2.0*diagonal, upper], [-1, 0, 1])

    # Getting the matrix C
    I = sp.eye(N)
    C = I + (k/(h**2))*G
    
    # Obtaining u(1,x)
    sol = lin.matrix_power(C.toarray(), M) @ bc
    print(sol)
    return sol

eulerexplicit(200,60000)
# Out:
# ---------------------------------------------------------------------------
# FloatingPointError                        Traceback (most recent call last)
# Cell In[45], line 48
#      45     print(sol)
#      46     return sol
# ---> 48 eulerexplicit(200,6000000)
#
# Cell In[45], line 44, in eulerexplicit(N, M)
#      41 C = I + (k/(h**2))*G
#      43 # Obtaining u(1,x)
# ---> 44 sol = lin.matrix_power(C.toarray(), M) @ bc
#      45 print(sol)
#      46 return sol
#
# File c:\Users\hugob\anaconda3\Lib\site-packages\numpy\linalg\_linalg.py:732, in matrix_power(a, n)
#     730 z = result = None
#     731 while n > 0:
# --> 732     z = a if z is None else fmatmul(z, z)
#     733     n, bit = divmod(n, 2)
#     734     if bit:
#
# File c:\Users\hugob\anaconda3\Lib\site-packages\numpy\linalg\_linalg.py:3437, in matmul(x1, x2)
#    3356 @array_function_dispatch(_matmul_dispatcher)
#    3357 def matmul(x1, x2, /):
#    3358     """
#    3359     Computes the matrix product.
#    3360
#    (...)
#    3435
#    3436     """
# -> 3437     return _core_matmul(x1, x2)
#
# FloatingPointError: underflow encountered in matmul
